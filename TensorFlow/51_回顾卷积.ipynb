# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\python\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.13.3 in e:\python\lib\site-packages (from opencv-python) (1.19.5)
# WARNING: Ignoring invalid distribution -umpy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (e:\python\lib\site-packages)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
img=plt.imread("zbs.jpg")
plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import cv2
import numpy as np

# %matplotlib notebook
kernel=np.array([
    [1,1,1],
    [1,1,1],
    [1,1,1]
    
])
res=cv2.filter2D(img,-1,kernel)
plt.imshow(res)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
kernel=np.array([
    [0,0,0],
    [1,1,1],
    [0,0,0]
    
])
res=cv2.filter2D(img,-1,kernel)
plt.imshow(res)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
kernel=np.array([
    [0,1,0],
    [0,1,0],
    [0,1,0]
    
])
res=cv2.filter2D(img,-1,kernel)
plt.imshow(res)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
kernel=np.array([
    [0,1,0],
    [-1,5,-1],
    [0,-1,0]
    
])
res=cv2.filter2D(img,-1,kernel)
plt.imshow(res)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
kernel=np.array([
    [0,1,0],
    [1,-4,1],
    [0,1,0]
    
])
res=cv2.filter2D(img,-1,kernel)
plt.imshow(res)
# Out:
# <img src="data:image/png;base64,..." width="640">
